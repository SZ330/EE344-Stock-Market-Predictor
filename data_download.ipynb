# %% [markdown]
# <a href="https://colab.research.google.com/github/SZ330/EE344-Stock-Market-Predictor/blob/main/data_download.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd

df = yf.download(
    "^VIX",
    start="1995-01-01",
    end="2025-12-31",
    auto_adjust=False,   # keep raw OHLC + Adj Close separately
    progress=False
)

df = df.reset_index()   # Date becomes a column
df.rename(columns={"Date":"Date"}, inplace=True)
df.to_csv("SPY_1995_2024_yfinance.csv", index=False)
print(df.head(), df.tail())
# Out:
# Price        Date Adj Close  Close   High    Low   Open Volume
# Ticker                 ^VIX   ^VIX   ^VIX   ^VIX   ^VIX   ^VIX
# 0      1995-01-03     14.25  14.25  14.71  13.39  14.09      0
# 1      1995-01-04     13.53  13.53  14.15  13.53  13.87      0
# 2      1995-01-05     13.50  13.50  14.19  13.37  13.70      0
# 3      1995-01-06     13.13  13.13  13.76  12.79  13.67      0
# 4      1995-01-09     13.33  13.33  14.08  13.21  13.53      0 Price        Date Adj Close  Close   High    Low   Open Volume
# Ticker                 ^VIX   ^VIX   ^VIX   ^VIX   ^VIX   ^VIX
# 7796   2025-12-23     14.00  14.00  14.45  13.64  14.09      0
# 7797   2025-12-24     13.47  13.47  14.16  13.38  14.09      0
# 7798   2025-12-26     13.60  13.60  14.29  13.52  14.12      0
# 7799   2025-12-29     14.20  14.20  15.08  13.99  14.69      0
# 7800   2025-12-30     14.33  14.33  14.62  14.04  14.43      0
